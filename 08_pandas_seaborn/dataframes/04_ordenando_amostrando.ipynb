# %%
import pandas as pd

# %% [markdown]
# # Ordenando DataFrames
# - Assim como nas séries, podemos usar o método `sort_values()`
# - Porém, precisamos informar a coluna para ordenação

# %%
nba = pd.read_csv("../data/nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values(by="Name")
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba.sort_values(by="Name", ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba.sort_values(by="Salary", ascending=False, inplace=True)
nba
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %% [markdown]
# - Por padrão, os valores com `NaN` são colocados no final
# - Veja o Salary aqui:

# %%
nba.tail()
# Out:
#               Name                    Team  Number Position   Age Height  \
# 350  Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353  Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397   Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409     Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457            NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College  Salary
# 350   165.0  Virginia Commonwealth     NaN
# 353   205.0                    NaN     NaN
# 397   210.0                    NaN     NaN
# 409   250.0           Fresno State     NaN
# 457     NaN                    NaN     NaN

# %% [markdown]
# - Porem, podemos alterar esse comportamento usando o parametro `na_position`:

# %%
nba.sort_values(by="Salary", ascending=False, inplace=True, na_position="first")
nba.head()
# Out:
#               Name                 Team  Number Position   Age Height  Weight  \
# 2     John Holland       Boston Celtics    30.0       SG  27.0    6-5   205.0
# 46     Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9   254.0
# 171  Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6   225.0
# 264  Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2   180.0
# 269   Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3   190.0
#
#                College  Salary
# 2    Boston University     NaN
# 46                Duke     NaN
# 171               Duke     NaN
# 264               UCLA     NaN
# 269            Detroit     NaN

# %% [markdown]
# ## Ordenando usando multiplas colunas
# - É igualmente fácil, apenas precisamos passar uma lista para o parametro `by` indicando a ordem das colunas a serem consideradas

# %%
nba.sort_values(by=["Name", "Salary", "Team"], ascending=[False, True, False], inplace=True)
nba.tail()
# Out:
#                Name                    Team  Number Position   Age Height  \
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College     Salary
# 404   237.0  Michigan State  1938840.0
# 328   210.0        Kentucky   525093.0
# 356   220.0         Arizona  4171680.0
# 152   161.0          Oregon  2250000.0
# 457     NaN             NaN        NaN

# %% [markdown]
# ## Ordenando pelo index
# - Assim como para séries, podemos ordenar pelos indices
# - Podemos usar o método `sort_index()`

# %%
nba.sort_index(ascending=True, inplace=True)
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # Criando um ranking
# - Podemos criar um rank usando o método `rank()`
# - Vamos supor que eu queria o ranking de cada jogador de acordo com o salário

# %%
nba["Salary"].fillna(0, inplace=True)
nba["Salary"].rank(ascending=False).astype(int)
# Out:
# 0       97
# 1      110
# 2      452
# 3      322
# 4      147
#       ...
# 453    241
# 454    383
# 455    214
# 456    367
# 457    452
# Name: Salary, Length: 458, dtype: int64

# %% [markdown]
# - Agora vamos criar uma nova coluna pra essa informação

# %%
nba["Rank Salary"] = nba["Salary"].rank(ascending=False).astype(int)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Rank Salary
# 0              Texas  7730337.0           97
# 1          Marquette  6796117.0          110
# 2  Boston University        0.0          452
# 3      Georgia State  1148640.0          322
# 4                NaN  5000000.0          147

# %% [markdown]
# # Obtendo os `n` maiores e menores valores
# - Vamos supor que queremos obter os `n` maiores e menores valores de uma coluna
# - Podemos resolver isso usando o método `sort_values()`
# - Porém, é mais interessante (e muitas vezes mais rápido) usar os métodos `nsmallest()` e `nlargest`
# - A ideia é similar ao `sort`, porém, ele retorna apenas os `n` desejados

# %% [markdown]
# - Vamos obter os 7 jogadores mais pesados da liga:

# %%
nba.nlargest(n=7, columns="Weight")
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 405    Nikola Pekovic  Minnesota Timberwolves    14.0        C  30.0   6-11
# 302  Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 330      Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
# 395      Jusuf Nurkic          Denver Nuggets    23.0        C  21.0    7-0
# 188    Andre Drummond         Detroit Pistons     0.0        C  22.0   6-11
# 41     Kevin Seraphin         New York Knicks     1.0        C  26.0   6-10
# 23        Brook Lopez           Brooklyn Nets    11.0        C  28.0    7-0
#
#      Weight      College      Salary  Rank Salary
# 405   307.0          NaN  12100000.0           54
# 302   290.0          NaN   1200000.0          314
# 330   289.0          NaN  13500000.0           43
# 395   280.0          NaN   1842000.0          270
# 188   279.0  Connecticut   3272091.0          199
# 41    278.0          NaN   2814000.0          226
# ...

# %% [markdown]
# - Assim como no sort, podemos colocar uma segunda coluna para desempate:

# %%
nba.nlargest(n=7, columns=["Weight", "Age"])
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 405    Nikola Pekovic  Minnesota Timberwolves    14.0        C  30.0   6-11
# 302  Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 330      Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
# 395      Jusuf Nurkic          Denver Nuggets    23.0        C  21.0    7-0
# 188    Andre Drummond         Detroit Pistons     0.0        C  22.0   6-11
# 41     Kevin Seraphin         New York Knicks     1.0        C  26.0   6-10
# 237     Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
#
#      Weight      College      Salary  Rank Salary
# 405   307.0          NaN  12100000.0           54
# 302   290.0          NaN   1200000.0          314
# 330   289.0          NaN  13500000.0           43
# 395   280.0          NaN   1842000.0          270
# 188   279.0  Connecticut   3272091.0          199
# 41    278.0          NaN   2814000.0          226
# ...

# %% [markdown]
# - Agora vamos obter os 7 jogadores mais novos da liga usando o `Weight` como desempate

# %%
nba.nsmallest(n=7, columns=["Age", "Weight"])
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 226     Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122      Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 445        Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 116  D'Angelo Russell      Los Angeles Lakers     1.0       PG  20.0    6-5
# 401        Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 393   Emmanuel Mudiay          Denver Nuggets     0.0       PG  20.0    6-5
# 62      Bruno Caboclo         Toronto Raptors    20.0       SF  20.0    6-9
#
#      Weight     College     Salary  Rank Salary
# 226   202.0        UNLV  1733040.0          275
# 122   206.0    Kentucky  2127840.0          257
# 445   190.0         NaN  3777720.0          181
# 116   195.0  Ohio State  5103120.0          142
# 401   195.0        Duke  1282080.0          305
# 393   200.0         NaN  3102240.0          205
# ...

# %% [markdown]
# - Uma ultima observação: esses métodos funcionam para um série também:

# %%
nba["Age"].nlargest(n=6)
# Out:
# 298    40.0
# 304    40.0
# 400    40.0
# 102    39.0
# 261    39.0
# 101    38.0
# Name: Age, dtype: float64

# %% [markdown]
# # Usando o método `sample` para pegar amostras aleatórias
# - O método `sample` retorna uma quantidade de dados de maneira aleatório
#     - Podemos usar o parâmetro `n` para um valor exato ou `frac` para uma %

# %%
nba.sample(n=2)
# Out:
#               Name             Team  Number Position   Age Height  Weight  \
# 246   Clint Capela  Houston Rockets    15.0       PF  22.0   6-10   240.0
# 11   Isaiah Thomas   Boston Celtics     4.0       PG  27.0    5-9   185.0
#
#         College     Salary  Rank Salary
# 246         NaN  1242720.0          310
# 11   Washington  6912869.0          109

# %%
nba.sample(n=2)
# Out:
#                 Name                  Team  Number Position   Age Height  \
# 291  Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0    6-5
# 251    Dwight Howard       Houston Rockets    12.0        C  30.0   6-11
#
#      Weight           College      Salary  Rank Salary
# 291   220.0  UC Santa Barbara     55722.0          444
# 251   265.0               NaN  22359364.0            4

# %% [markdown]
# - Observe que cada execução resulta em um valor diferente
# - também podemos usar frac, que representa a % de 0 a 1.0

# %%
nba.sample(frac=0.01) # 1%
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 225  Greivis Vasquez         Milwaukee Bucks    21.0       PG  29.0    6-6
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 431         Ed Davis  Portland Trail Blazers    17.0        C  27.0   6-10
# 112  Marcelo Huertas      Los Angeles Lakers     9.0       PG  33.0    6-3
# 344      Joe Johnson              Miami Heat     2.0       SF  34.0    6-7
#
#      Weight         College     Salary  Rank Salary
# 225   217.0        Maryland  6600000.0          111
# 409   250.0    Fresno State        0.0          452
# 431   240.0  North Carolina  6980802.0          108
# 112   200.0             NaN   525093.0          415
# 344   240.0        Arkansas   261894.0          426

# %% [markdown]
# - Outra opção é setar o `axis` que indica se queremos amostrar linhas ou colunas
#     - `axis = 0` -> Linhas
#     - `axis = 1` -> Colunas
#     - O padrão é 0
# - Vamos usar `axis=1` com `n=3` para obter 3 colunas aleatórias:

# %%
nba.sample(n=3, axis=1).head()
# Out:
#              College     Salary  Rank Salary
# 0              Texas  7730337.0           97
# 1          Marquette  6796117.0          110
# 2  Boston University        0.0          452
# 3      Georgia State  1148640.0          322
# 4                NaN  5000000.0          147

# %% [markdown]
# - **Pro tip**: se quisermos embaralhar os dados, podemos usar esse método da seguinte forma:

# %%
nba_rand = nba.sample(frac=1.0, random_state=8)
nba_rand.head()
# Out:
#                Name                   Team  Number Position   Age Height  \
# 27       Henry Sims          Brooklyn Nets    14.0        C  26.0   6-10
# 78     Andrew Bogut  Golden State Warriors    12.0        C  31.0    7-0
# 306     Tony Parker      San Antonio Spurs     9.0       PG  34.0    6-2
# 131    Ronnie Price           Phoenix Suns    14.0       PG  32.0    6-2
# 273  Alex Stepheson      Memphis Grizzlies    35.0       PF  28.0   6-10
#
#      Weight      College      Salary  Rank Salary
# 27    248.0   Georgetown    947276.0          367
# 78    260.0         Utah  13800000.0           40
# 306   185.0          NaN  13437500.0           45
# 131   190.0  Utah Valley    947276.0          367
# 273   270.0          USC         0.0          452

# %% [markdown]
# - O parametro `random_state` é apenas uma semente para reprodução
